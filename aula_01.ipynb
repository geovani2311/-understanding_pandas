# %% [markdown]
# <a href="https://colab.research.google.com/github/geovani2311/-understanding_pandas/blob/main/aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Entendendo Pandas**

# %% [markdown]
# **aula_01**

# %%
# importando bibliotecas
import pandas as pd
import numpy as np

# %%
#lista de strings
labels = ['a','b','c']

#lista de números
minha_lista = [10,20,30]

#array de números
arr = np.array ([10,20,30])

#dicionário de strings e números
d = {'a':10, 'b':20, 'c':30}

# %%
#retornando uma Serie da lista de string
pd.Series(labels)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
#criando uma Serie com lista de string e lista de números, podemos juntar em uma Seria por mais que sejam listas diferentes
pd.Series(data=labels, index=minha_lista)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object

# %%
#Criando Serie com lista de string
pd.Series(labels,minha_lista)
# Out:
# 10    a
# 20    b
# 30    c
# dtype: object

# %%
#retornado uma Serie com dicionário de strings
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
#Neste código abaixo, a Serie criada é atribuida á uma variavel "ser1"
ser1 = pd.Series([1,2,3,4], index= ["Brasil","Korea do Sul","Estados Unidos","Japão"])

# %%
ser2 = pd.Series([1,2,3,4], index= ["Brasil","Japão","Estados Unidos","Korea do Sul"])

# %%
#juntando as duas Series
ser1 + ser2
# Out:
# Brasil            2
# Estados Unidos    6
# Japão             6
# Korea do Sul      6
# dtype: int64

# %% [markdown]
# **Manipulando**

# %%
from numpy.random import randn

# %%
#montando um DataFrame com os números aleatorios
df = pd.DataFrame(randn(5,4), index = ["A","B","C","D","E"], columns = "W X Y Z".split())
df
# Out:
#           W         X         Y         Z
# A -0.850899 -0.022432  1.107481  0.129549
# B  0.189944 -0.031704 -0.868684 -0.791679
# C  0.792739  0.118840 -0.433341  1.567946
# D -0.889542  1.206430 -0.593737  0.446184
# E  0.536864 -0.322000 -0.699684 -0.964438

# %%
#como retornar a Serie de uma coluna
df['W']
# Out:
# A   -0.850899
# B    0.189944
# C    0.792739
# D   -0.889542
# E    0.536864
# Name: W, dtype: float64

# %%
#como retornar o DataFrame de uma coluna:
df[['W']]
# Out:
#           W
# A -0.850899
# B  0.189944
# C  0.792739
# D -0.889542
# E  0.536864

# %%
#como criar nova coluna com valores de outra
df["new"] = df["W"]
df
# Out:
#           W         X         Y         Z       new
# A -0.850899 -0.022432  1.107481  0.129549 -0.850899
# B  0.189944 -0.031704 -0.868684 -0.791679  0.189944
# C  0.792739  0.118840 -0.433341  1.567946  0.792739
# D -0.889542  1.206430 -0.593737  0.446184 -0.889542
# E  0.536864 -0.322000 -0.699684 -0.964438  0.536864

# %%
#Como criar nova coluna com contas aritmética de outras colunas
df["new"] = df["Z"] * df["W"] *100
df
# Out:
#           W         X         Y         Z         new
# A -0.850899 -0.022432  1.107481  0.129549  -11.023320
# B  0.189944 -0.031704 -0.868684 -0.791679  -15.037427
# C  0.792739  0.118840 -0.433341  1.567946  124.297155
# D -0.889542  1.206430 -0.593737  0.446184  -39.689987
# E  0.536864 -0.322000 -0.699684 -0.964438  -51.777181

# %%
#como apagar colunas
df.drop('new', axis = 1)

# axis = 1 - coluna
# axis = 0 - linha

#apagou a coluna porém ainda mantém uma copia da original - df.drop('new', inplace = true, axis = 1)
# Out:
#           W         X         Y         Z
# A -0.850899 -0.022432  1.107481  0.129549
# B  0.189944 -0.031704 -0.868684 -0.791679
# C  0.792739  0.118840 -0.433341  1.567946
# D -0.889542  1.206430 -0.593737  0.446184
# E  0.536864 -0.322000 -0.699684 -0.964438

# %%
#Como selecionar linhas e colunas
df.loc[['A', 'B'], ['W']]
# Out:
#           W
# A -0.850899
# B  0.189944
